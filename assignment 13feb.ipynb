# %%
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
#python requires the user defined exception to be inherited from base exception if exception class is not inherited then user defined class will not be considered as exception class and so type error will occur and hence raise statement to raise exception will not be able to handle it

# %%
class valid_age(Exception):    #inheriting exception class
    def __init__(self,msg):
        self.msg=msg

# %%
def validage(age):
    if age<0:
        raise valid_age('age should not be less than zero') # raise keyword
    elif age>100:
        raise valid_age('age should be less than 100')
    else:
        print('age is valid')

# %%
try:
    age=int(input('enter your age')) 
    validage(age)
except valid_age as e:
    print(e)
# Out:
# enter your age -25
# age should not be less than zero

# %%
class valid_age():    # not inheriting exception class therefor not 
    def __init__(self,msg):
        self.msg=msg

# %%
def validage(age):
    if age<0:
        raise valid_age('age should not be less than zero') # raise keyword
    elif age>100:
        raise valid_age('age should be less than 100')
    else:
        print('age is valid')

# %%
try:
    age=int(input('enter your age')) 
    validage(age)
except valid_age as e:
    print(e)
# Out:
# enter your age -25
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       2     age=int(input('enter your age'))
# ----> 3     validage(age)
#       4 except valid_age as e:
#
# Cell In[14], line 3, in validage(age)
#       2 if age<0:
# ----> 3     raise valid_age('age should not be less than zero') # raise keyword
#       4 elif age>100:
#
# TypeError: exceptions must derive from BaseException
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2     age=int(input('enter your age'))
#       3     validage(age)
# ----> 4 except valid_age as e:
#       5     print(e)
#
# TypeError: catching classes that do not inherit from BaseException is not allowed

# %%
# Q2. Write a python program to print Python Exception Hierarchy.
# Inbuilt exceptions:
# Import the inspect module
import inspect
print("The class hierarchy for built-in exceptions is:")
inspect.getclasstree(inspect.getmro(Exception))
def classtree(cls, indent=0):
    print('.' * indent, cls.__name__)
    for subcls in cls.__subclasses__():
        classtree(subcls, indent + 3)
classtree(Exception)
# Out:
# The class hierarchy for built-in exceptions is:
#  Exception
# ... TypeError
# ...... FloatOperation
# ...... MultipartConversionError
# ... StopAsyncIteration
# ... StopIteration
# ... ImportError
# ...... ModuleNotFoundError
# ...... ZipImportError
# ... OSError
# ...... ConnectionError
# ......... BrokenPipeError
# ......... ConnectionAbortedError
# ......... ConnectionRefusedError
# ......... ConnectionResetError
# ............ RemoteDisconnected
# ...... BlockingIOError
# ...... ChildProcessError
# ...... FileExistsError
# ...... FileNotFoundError
# ...... IsADirectoryError
# ...... NotADirectoryError
# ...... InterruptedError
# ......... InterruptedSystemCall
# ...... PermissionError
# ...... ProcessLookupError
# ...... TimeoutError
# ...... UnsupportedOperation
# ...... itimer_error
# ...... herror
# ...... gaierror
# ...... SSLError
# ......... SSLCertVerificationError
# ......... SSLZeroReturnError
# ......... SSLWantWriteError
# ......... SSLWantReadError
# ...

# %%
#Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
# zerodivisionerror,floatingpointerror,overflowerror
try:
    1/0
except ZeroDivisionError as e: #zero division error if number is divided by 0
    print(e)
# Out:
# division by zero

# %%
i=1
try:
    f = 3.0**i
    for i in range(100):
        print (i,f)
        f = f ** 2
except OverflowError as err:
    print ('Overflowed after ', f, err)
# Out:
# 0 3.0
# 1 9.0
# 2 81.0
# 3 6561.0
# 4 43046721.0
# 5 1853020188851841.0
# 6 3.4336838202925124e+30
# 7 1.1790184577738583e+61
# 8 1.3900845237714473e+122
# 9 1.9323349832288915e+244
# Overflowed after  1.9323349832288915e+244 (34, 'Numerical result out of range')

# %%
#Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
#The LookupError exception in Python forms the base class for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively
#index error
try:
    l=[1,2,3,4,5]
    l[6]
except LookupError as e:
    print(e)
# Out:
# list index out of range

# %%
#key error
try:
    d={'rollno':5,'name':'nikhil'}
    d['age']
except LookupError as e:
    print(e)
# Out:
# 'age'

# %%
#Q5. Explain ImportError. What is ModuleNotFoundError?
#In Python, when we want to include the module contents in the program then we have to import these specific modules in the program. So to do this we use “import” keyword such as import statement with the module name. When writing this statement and the specified module is not written properly or the imported module is not found in the Python library then the Python interpreter throws an error known as ImportError. and such problems also known as ModuleNotFoundError in the latest versions of Python such as 3.6 and newer versions.

# %%
import request
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import request
#
# ModuleNotFoundError: No module named 'request'

# %%
#In the below program, we can see another way of importing modules. This throws ImportError if the module is not present in the private Python library.

# %%
from crypt import pwd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from crypt import pwd
#
# ImportError: cannot import name 'pwd' from 'crypt' (/opt/conda/lib/python3.10/crypt.py)

# %%
# q5 List down some best practices for exception handling in python.

# %%
# always use specific exceptions and not superclass
# print always a valid msg
# always try to log the errors you are receiving
# always avoid using multiple exception handling
# always prepare proper documentation
# cleanup all the resources and files using close()
